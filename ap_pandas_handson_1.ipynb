# %% [markdown]
# <a href="https://colab.research.google.com/github/atul2017/AIFoundationPandasNumpy/blob/main/ap_pandas_handson_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Why do we need pandas? - Numpy is really good at handling big data because of vectorization where there is level of parrallelism is achieved but the Numpy is homogenous and it can handle only one type of data at a time.
#
# This is where Pandas power comes where it can handle hetrogenous data.

# %%
# Downloading and unziping the dataset - The following are the Unix commands and you are interacting with computer using the following commands
#this is the reason you also start the command below starts with ! sign. This is google collab command line which is intergated here.

# !wget https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/100/375/original/zomato_dataset.zip
# !unzip zomato_dataset.zip
# !mv zomato_dataset.csv .
# Out:
# --2025-04-24 02:31:32--  https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/100/375/original/zomato_dataset.zip
# Resolving d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)... 13.224.9.103, 13.224.9.181, 13.224.9.129, ...
# Connecting to d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)|13.224.9.103|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72602133 (69M) [application/zip]
# Saving to: ‘zomato_dataset.zip’
#
# zomato_dataset.zip  100%[===================>]  69.24M  58.0MB/s    in 1.2s
#
# 2025-04-24 02:31:33 (58.0 MB/s) - ‘zomato_dataset.zip’ saved [72602133/72602133]
#
# Archive:  zomato_dataset.zip
#   inflating: zomato_dataset.csv
# mv: 'zomato_dataset.csv' and './zomato_dataset.csv' are the same file

# %%
import pandas as pd

# %%
df = pd.read_csv("zomato_dataset.csv")

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00cf07b74dcd> in <cell line: 0>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
df.tail()
# Out:
#                                                      url  \
# 23188  https://www.zomato.com/bangalore/izakaya-gastr...
# 23189  https://www.zomato.com/bangalore/m-bar-bengalu...
# 23190  https://www.zomato.com/bangalore/keys-cafe-key...
# 23191  https://www.zomato.com/bangalore/bhagini-2-whi...
# 23192  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 23188  2nd Floor, Iona, Virginia Mall, Whitefield Mai...
# 23189  Bengaluru Marriott Hotel, 75, 8th Road, EPIP A...
# 23190  Keys Hotel, 6, 1st Phase Industrial Area, Near...
# 23191  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 23192  Sheraton Grand Bengaluru Whitefield Hotel & Co...
#
#                                                     name online_order  \
# 23188                                 Izakaya Gastro Pub          Yes
# 23189        M Bar - Bengaluru Marriott Hotel Whitefield           No
# ...

# %%
df.shape
# Out:
# (23193, 17)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23193 entries, 0 to 23192
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          23193 non-null  object
#  1   address                      23193 non-null  object
#  2   name                         23193 non-null  object
#  3   online_order                 23193 non-null  object
#  4   book_table                   23193 non-null  object
#  5   rate                         23193 non-null  object
#  6   votes                        23193 non-null  int64
#  7   phone                        23193 non-null  object
#  8   location                     23193 non-null  object
#  9   rest_type                    23193 non-null  object
#  10  dish_liked                   23193 non-null  object
#  11  cuisines                     23193 non-null  object
#  12  approx_cost(for two people)  23193 non-null  object
# ...

# %% [markdown]
# One of the difference between Numpy and pandas - Pandas data has column name versus Numpy we have indexes for rows and columns

# %%
#viewing specific column
df['rate']
# Out:
# 0         4.1/5
# 1         4.1/5
# 2         3.8/5
# 3         3.7/5
# 4         3.8/5
#           ...
# 23188    3.8 /5
# 23189    3.9 /5
# 23190    2.8 /5
# 23191    2.5 /5
# 23192    4.3 /5
# Name: rate, Length: 23193, dtype: object

# %%
df['menu_item']
# Out:
# 0        []
# 1        []
# 2        []
# 3        []
# 4        []
#          ..
# 23188    []
# 23189    []
# 23190    []
# 23191    []
# 23192    []
# Name: menu_item, Length: 23193, dtype: object

# %%
#python dictionary
cls = {'teacher':'Atul','son':'Reyan','total':5}
cls
# Out:
# {'teacher': 'Atul', 'son': 'Reyan', 'total': 5}

# %%
cls['son']
# Out:
# 'Reyan'

# %%
# Creating a DataFrame from a dictionary
data = {
    "Restaurant": ["R1", "R2", "R3"],
    "Votes": [120, 240, 150],
    "Rating": [4.1, 4.5, 3.9]
}

pd.DataFrame(data)
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9

# %%
type(df['rate']) #Pandas have two set of datatype - series which is nothing but the column and once you put all series together then it becomes dataframe.
#the dataframe is nothing but the collection of series
#series is the data structure and type of the series is object
#series is nothing but Numpy array underneath whihc is one dimensional array
#collection of hetrogenous one dimenional arrays is nothing but dataframe
# Out:
# pandas.core.series.Series

# %%
df.votes
# Out:
# 0        775
# 1        787
# 2        918
# 3         88
# 4        166
#         ...
# 23188    128
# 23189     77
# 23190    161
# 23191     81
# 23192    236
# Name: votes, Length: 23193, dtype: int64

# %%
type(df.votes)
# Out:
# pandas.core.series.Series

# %%
df['votes','name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('votes', 'name')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-d00719f74d02> in <cell line: 0>()
# ----> 1 df['votes','name']
#
# ...

# %%
df[['votes','name']]
# Out:
#        votes                                               name
# 0        775                                              Jalsa
# 1        787                                     Spice Elephant
# 2        918                                    San Churro Cafe
# 3         88                              Addhuri Udupi Bhojana
# 4        166                                      Grand Village
# ...      ...                                                ...
# 23188    128                                 Izakaya Gastro Pub
# 23189     77        M Bar - Bengaluru Marriott Hotel Whitefield
# 23190    161                             Keys Cafe - Keys Hotel
# 23191     81                                            Bhagini
# 23192    236  Chime - Sheraton Grand Bengaluru Whitefield Ho...
#
# [23193 rows x 2 columns]

# %%
col = ['name','url']
df[col]
# Out:
#                                                     name  \
# 0                                                  Jalsa
# 1                                         Spice Elephant
# 2                                        San Churro Cafe
# 3                                  Addhuri Udupi Bhojana
# 4                                          Grand Village
# ...                                                  ...
# 23188                                 Izakaya Gastro Pub
# 23189        M Bar - Bengaluru Marriott Hotel Whitefield
# 23190                             Keys Cafe - Keys Hotel
# 23191                                            Bhagini
# 23192  Chime - Sheraton Grand Bengaluru Whitefield Ho...
#
#                                                      url
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# ...

# %%
df.rename(columns={'name':'real_name'})
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 23188  https://www.zomato.com/bangalore/izakaya-gastr...
# 23189  https://www.zomato.com/bangalore/m-bar-bengalu...
# 23190  https://www.zomato.com/bangalore/keys-cafe-key...
# 23191  https://www.zomato.com/bangalore/bhagini-2-whi...
# 23192  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
df.rename(columns={'real_name':'name'})
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 23188  https://www.zomato.com/bangalore/izakaya-gastr...
# 23189  https://www.zomato.com/bangalore/m-bar-bengalu...
# 23190  https://www.zomato.com/bangalore/keys-cafe-key...
# 23191  https://www.zomato.com/bangalore/bhagini-2-whi...
# 23192  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
df.rename(columns={"votes":"Voting", "rate":"Rating"})
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
df = df.rename(columns={"votes":"Voting", "rate":"Rating"})
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table Rating  Voting                             phone  \
# 0          Yes        Yes  4.1/5     775    080 42297555\r\n+91 9743772233
# ...

# %%
#Inplace true means it makes change in the eixsting dataframe. If the inplace false that means it creates the new dataframe with the changes and return new dataframe
df.rename(columns={'book_table':'book_tables'}, inplace=True)
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_tables Rating  Voting                             phone  \
# 0          Yes         Yes  4.1/5     775    080 42297555\r\n+91 9743772233
# ...

# %%
df['Voting'] * 2 #it does not change the value in dataframe. You need to initialize to dataframe through =
# Out:
# 0        1550
# 1        1574
# 2        1836
# 3         176
# 4         332
#          ...
# 23188     256
# 23189     154
# 23190     322
# 23191     162
# 23192     472
# Name: Voting, Length: 23193, dtype: int64

# %%
df['Voting']
# Out:
# 0        775
# 1        787
# 2        918
# 3         88
# 4        166
#         ...
# 23188    128
# 23189     77
# 23190    161
# 23191     81
# 23192    236
# Name: Voting, Length: 23193, dtype: int64

# %%
df.head(10) #shows the initial 10 rows
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
# 5  https://www.zomato.com/bangalore/timepass-dinn...
# 6  https://www.zomato.com/bangalore/onesta-banash...
# 7  https://www.zomato.com/bangalore/penthouse-caf...
# 8  https://www.zomato.com/bangalore/smacznego-ban...
# 9  https://www.zomato.com/bangalore/caf%C3%A9-dow...
#
#                                              address  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2  1112, Next to KIMS Medical College, 17th Cross...
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# 5  37, 5-1, 4th Floor, Bosco Court, Gandhi Bazaar...
# ...

# %%
s = "4.1/5"
s[:-2]
# Out:
# '4.1'

# %%
df['only_rating'] = [ i[:-2] for i in df["Rating"]]
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 23188  https://www.zomato.com/bangalore/izakaya-gastr...
# 23189  https://www.zomato.com/bangalore/m-bar-bengalu...
# 23190  https://www.zomato.com/bangalore/keys-cafe-key...
# 23191  https://www.zomato.com/bangalore/bhagini-2-whi...
# 23192  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
#axis =0 means column wise and axis =1 traverse rowwise
df.drop("Rating", axis=1, inplace=True)

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_tables  Voting                             phone  \
# 0          Yes         Yes     775    080 42297555\r\n+91 9743772233
# ...

# %%
#Finding unique values in the cuisine column
df["cuisines"].unique()
# Out:
# array(['North Indian, Mughlai, Chinese', 'Chinese, North Indian, Thai',
#        'Cafe, Mexican, Italian', ..., 'Andhra, Hyderabadi, Biryani',
#        'Andhra, North Indian, South Indian', 'Thai, Chinese, Momos'],
#       dtype=object)

# %%
#Count of how many unqiue values in the cuisine columns
df["cuisines"].nunique()
# Out:
# 1687

# %%
df["name"].nunique()
# Out:
# 3159

# %%
df['rest_type'].nunique()
# Out:
# 73

# %%
df['rest_type'].value_counts()
# Out:
# rest_type
# Casual Dining                7349
# Quick Bites                  5240
# Cafe                         2325
# Dessert Parlor               1076
# Casual Dining, Bar            984
#                              ...
# Fine Dining, Microbrewery       5
# Club, Casual Dining             4
# Dessert Parlor, Kiosk           2
# Dhaba                           1
# Food Court, Casual Dining       1
# Name: count, Length: 73, dtype: int64

# %%
df['rest_type'].value_counts(normalize=True)
# Out:
# rest_type
# Casual Dining                0.316863
# Quick Bites                  0.225930
# Cafe                         0.100246
# Dessert Parlor               0.046393
# Casual Dining, Bar           0.042427
#                                ...
# Fine Dining, Microbrewery    0.000216
# Club, Casual Dining          0.000172
# Dessert Parlor, Kiosk        0.000086
# Dhaba                        0.000043
# Food Court, Casual Dining    0.000043
# Name: proportion, Length: 73, dtype: float64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=23193, step=1)

# %% [markdown]
# Implicit & explicit indexes
#
# Implicit Indexes - These are the indexes starts 0 to ....
#
# Explicit indexes - You can name one of the column as explicit indexes for example if name is one of the column then you can set it as explicit indexes and it will show up in first column and bold. Now you can refer any lines in the frame using name as indexes

# %%
df_new = df.set_index("name") #explicit indexes
df_new.head()
# Out:
#                                                                      url  \
# name
# Jalsa                  https://www.zomato.com/bangalore/jalsa-banasha...
# Spice Elephant         https://www.zomato.com/bangalore/spice-elephan...
# San Churro Cafe        https://www.zomato.com/SanchurroBangalore?cont...
# Addhuri Udupi Bhojana  https://www.zomato.com/bangalore/addhuri-udupi...
# Grand Village          https://www.zomato.com/bangalore/grand-village...
#
#                                                                  address  \
# name
# Jalsa                  942, 21st Main Road, 2nd Stage, Banashankari, ...
# Spice Elephant         2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# San Churro Cafe        1112, Next to KIMS Medical College, 17th Cross...
# Addhuri Udupi Bhojana  1st Floor, Annakuteera, 3rd Stage, Banashankar...
# Grand Village          10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
#
#                       online_order book_tables  Voting  \
# name
# ...

# %%
df_new.index #shows the indexes in the df_new frame
# Out:
# Index(['Jalsa', 'Spice Elephant', 'San Churro Cafe', 'Addhuri Udupi Bhojana',
#        'Grand Village', 'Timepass Dinner', 'Onesta', 'Penthouse Cafe',
#        'Smacznego', 'CafÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ© Down The Alley',
#        ...
#        'BAR BAR', 'The Beer Cafe', 'Pablo's Gastrobar', 'Oliver's Pub & Diner',
#        'Smaaash', 'Izakaya Gastro Pub',
#        'M Bar - Bengaluru Marriott Hotel Whitefield', 'Keys Cafe - Keys Hotel',
#        'Bhagini', 'Chime - Sheraton Grand Bengaluru Whitefield Hotel &...'],
#       dtype='object', name='name', length=23193)

# %%
# .iloc for implicit indexing

df.iloc[0]
# Out:
# url                            https://www.zomato.com/bangalore/jalsa-banasha...
# address                        942, 21st Main Road, 2nd Stage, Banashankari, ...
# name                                                                       Jalsa
# online_order                                                                 Yes
# book_tables                                                                  Yes
# Voting                                                                       775
# phone                                             080 42297555\r\n+91 9743772233
# location                                                            Banashankari
# rest_type                                                          Casual Dining
# dish_liked                     Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# cuisines                                          North Indian, Mughlai, Chinese
# approx_cost(for two people)                                              '800.0'
# ...

# %%
print(type(df.iloc[0]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df.iloc[0,1] #zero index and first column in above dataset
# Out:
# '942, 21st Main Road, 2nd Stage, Banashankari, Bangalore'

# %%
df.iloc[1]
# Out:
# url                            https://www.zomato.com/bangalore/spice-elephan...
# address                        2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# name                                                              Spice Elephant
# online_order                                                                 Yes
# book_tables                                                                   No
# Voting                                                                       787
# phone                                                               080 41714161
# location                                                            Banashankari
# rest_type                                                          Casual Dining
# dish_liked                     Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# cuisines                                             Chinese, North Indian, Thai
# approx_cost(for two people)                                              '800.0'
# ...

# %%
df.iloc[1,3] #when you have , in the brackets then we are talking about the row and column here and the value should be first indexes that means the second row from the dataframe and third column (indexing starts from zero)
# Out:
# 'Yes'

# %%
df.iloc[1:3] #if there is : in brackets that means it is index range which does not include the third index that means only display dataframe rows from index 1 to 2
# Out:
#                                                  url  \
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
#
#                                              address             name  \
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...   Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...  San Churro Cafe
#
#   online_order book_tables  Voting           phone      location  \
# 1          Yes          No     787    080 41714161  Banashankari
# 2          Yes          No     918  +91 9663487993  Banashankari
#
#              rest_type                                         dish_liked  \
# 1        Casual Dining  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Cafe, Casual Dining  Churros, Cannelloni, Minestrone Soup, Hot Choc...
#
#                       cuisines approx_cost(for two people)  \
# 1  Chinese, North Indian, Thai                     '800.0'
# ...

# %%
df.iloc[1:10:5]
# Out:
#                                                  url  \
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 6  https://www.zomato.com/bangalore/onesta-banash...
#
#                                              address            name  \
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...  Spice Elephant
# 6  2469, 3rd Floor, 24th Cross, Opposite BDA Comp...          Onesta
#
#   online_order book_tables  Voting                         phone  \
# 1          Yes          No     787                  080 41714161
# 6          Yes         Yes    2556  080 48653961\r\n080 48655715
#
#        location            rest_type  \
# 1  Banashankari        Casual Dining
# 6  Banashankari  Casual Dining, Cafe
#
#                                           dish_liked  \
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 6  Farmhouse Pizza, Chocolate Banana, Virgin Moji...
#
#                       cuisines approx_cost(for two people)  \
# ...

# %%
df.iloc[-1] #Anytime you see -1 then it is always the last row in the dataframe
# Out:
# url                            https://www.zomato.com/bangalore/chime-sherato...
# address                        Sheraton Grand Bengaluru Whitefield Hotel & Co...
# name                           Chime - Sheraton Grand Bengaluru Whitefield Ho...
# online_order                                                                  No
# book_tables                                                                  Yes
# Voting                                                                       236
# phone                                                               080 49652769
# location                                              ITPL Main Road, Whitefield
# rest_type                                                                    Bar
# dish_liked                                          Cocktails, Pizza, Buttermilk
# cuisines                                                             Finger Food
# approx_cost(for two people)                                             '2500.0'
# ...

# %%
df.iloc[::-1] #will reverse the rows order and print that means last row will print first .....
# Out:
#                                                      url  \
# 23192  https://www.zomato.com/bangalore/chime-sherato...
# 23191  https://www.zomato.com/bangalore/bhagini-2-whi...
# 23190  https://www.zomato.com/bangalore/keys-cafe-key...
# 23189  https://www.zomato.com/bangalore/m-bar-bengalu...
# 23188  https://www.zomato.com/bangalore/izakaya-gastr...
# ...                                                  ...
# 4      https://www.zomato.com/bangalore/grand-village...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
#
#                                                  address  \
# 23192  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 23191  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 23190  Keys Hotel, 6, 1st Phase Industrial Area, Near...
# ...

# %%
df.loc[1]
# Out:
# url                            https://www.zomato.com/bangalore/spice-elephan...
# address                        2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# name                                                              Spice Elephant
# online_order                                                                 Yes
# book_tables                                                                   No
# Voting                                                                       787
# phone                                                               080 41714161
# location                                                            Banashankari
# rest_type                                                          Casual Dining
# dish_liked                     Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# cuisines                                             Chinese, North Indian, Thai
# approx_cost(for two people)                                              '800.0'
# ...

# %%
df.iloc[1]
# Out:
# url                            https://www.zomato.com/bangalore/spice-elephan...
# address                        2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# name                                                              Spice Elephant
# online_order                                                                 Yes
# book_tables                                                                   No
# Voting                                                                       787
# phone                                                               080 41714161
# location                                                            Banashankari
# rest_type                                                          Casual Dining
# dish_liked                     Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# cuisines                                             Chinese, North Indian, Thai
# approx_cost(for two people)                                              '800.0'
# ...

# %%
df_new.head()
# Out:
#                                                                      url  \
# name
# Jalsa                  https://www.zomato.com/bangalore/jalsa-banasha...
# Spice Elephant         https://www.zomato.com/bangalore/spice-elephan...
# San Churro Cafe        https://www.zomato.com/SanchurroBangalore?cont...
# Addhuri Udupi Bhojana  https://www.zomato.com/bangalore/addhuri-udupi...
# Grand Village          https://www.zomato.com/bangalore/grand-village...
#
#                                                                  address  \
# name
# Jalsa                  942, 21st Main Road, 2nd Stage, Banashankari, ...
# Spice Elephant         2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# San Churro Cafe        1112, Next to KIMS Medical College, 17th Cross...
# Addhuri Udupi Bhojana  1st Floor, Annakuteera, 3rd Stage, Banashankar...
# Grand Village          10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
#
#                       online_order book_tables  Voting  \
# name
# ...

# %%
df_new.iloc[1]
# Out:
# url                            https://www.zomato.com/bangalore/spice-elephan...
# address                        2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# online_order                                                                 Yes
# book_tables                                                                   No
# Voting                                                                       787
# phone                                                               080 41714161
# location                                                            Banashankari
# rest_type                                                          Casual Dining
# dish_liked                     Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# cuisines                                             Chinese, North Indian, Thai
# approx_cost(for two people)                                              '800.0'
# reviews_list                   [('Rated 4.0', 'RATED\n  Had been here for din...
# ...

# %%
df_new.iloc[2:4]
# Out:
#                                                                      url  \
# name
# San Churro Cafe        https://www.zomato.com/SanchurroBangalore?cont...
# Addhuri Udupi Bhojana  https://www.zomato.com/bangalore/addhuri-udupi...
#
#                                                                  address  \
# name
# San Churro Cafe        1112, Next to KIMS Medical College, 17th Cross...
# Addhuri Udupi Bhojana  1st Floor, Annakuteera, 3rd Stage, Banashankar...
#
#                       online_order book_tables  Voting           phone  \
# name
# San Churro Cafe                Yes          No     918  +91 9663487993
# Addhuri Udupi Bhojana           No          No      88  +91 9620009302
#
#                            location            rest_type  \
# name
# San Churro Cafe        Banashankari  Cafe, Casual Dining
# Addhuri Udupi Bhojana  Banashankari          Quick Bites
#
#                                                               dish_liked  \
# name
# ...

# %%
df_new.loc[2:4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-d5b70b623dbc> in <cell line: 0>()
# ----> 1 df_new.loc[2:4]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#    1192
#    1193     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1409         if isinstance(key, slice):
#    1410             self._validate_key(key, axis)
# -> 1411             return self._get_slice_axis(key, axis=axis)
#    1412         elif com.is_bool_indexer(key):
# ...

# %%
df_new.loc['Jalsa']
# Out:
#                                                      url  \
# name
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-maratha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-maratha...
#
#                                                  address online_order  \
# name
# Jalsa  942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# Jalsa  942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# ...

# %%
df_new.loc[["Jalsa","Tuk-Tuk"]]
# Out:
#                                                        url  \
# name
# Jalsa    https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-maratha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-maratha...
# Tuk-Tuk  https://www.zomato.com/bangalore/tuk-tuk-white...
#
#                                                    address online_order  \
# name
# Jalsa    942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# ...

# %%
df_new.loc[["Jalsa","Tuk-Tuk"],'address']
# Out:
# name
# Jalsa      942, 21st Main Road, 2nd Stage, Banashankari, ...
# Jalsa      942, 21st Main Road, 2nd Stage, Banashankari, ...
# Jalsa      942, 21st Main Road, 2nd Stage, Banashankari, ...
# Jalsa      942, 21st Main Road, 2nd Stage, Banashankari, ...
# Jalsa      942, 21st Main Road, 2nd Stage, Banashankari, ...
# Jalsa      942, 21st Main Road, 2nd Stage, Banashankari, ...
# Jalsa      25/7, Doddannakundi, Outer Ring Road, Mahadeva...
# Jalsa      942, 21st Main Road, 2nd Stage, Banashankari, ...
# Jalsa      942, 21st Main Road, 2nd Stage, Banashankari, ...
# Jalsa      942, 21st Main Road, 2nd Stage, Banashankari, ...
# Jalsa      25/7, Doddannakundi, Outer Ring Road, Mahadeva...
# Tuk-Tuk    2nd Floor, Food Court, VR Mall, Whitefield, Ba...
# Name: address, dtype: object

# %%
df_new.loc[["Jalsa","Tuk-Tuk"],'url':'book_tables'] #slicing on explicit indexing #Last column is included in explicit indexing - book_tables included in this example
# Out:
#                                                        url  \
# name
# Jalsa    https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-maratha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-maratha...
# Tuk-Tuk  https://www.zomato.com/bangalore/tuk-tuk-white...
#
#                                                    address online_order  \
# name
# Jalsa    942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# ...

# %%
df['Jalsa':'Grand Village'] #slicing will not work on duplicate index values
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-157b027f6038> in <cell line: 0>()
# ----> 1 df['Jalsa':'Grand Village'] #slicing will not work on duplicate index values
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4083         # Do we have a slicer (on rows)?
#    4084         if isinstance(key, slice):
# -> 4085             return self._getitem_slice(key)
#    4086
#    4087         # Do we have a (boolean) DataFrame?
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in _getitem_slice(self, key)
#    4347         # _convert_slice_indexer to determine if this slice is positional
#    4348         #  or label based, and if the latter, convert to positional
# -> 4349         slobj = self.index._convert_slice_indexer(key, kind="getitem")
#    4350         if isinstance(slobj, np.ndarray):
# ...

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_tables  Voting                             phone  \
# 0          Yes         Yes     775    080 42297555\r\n+91 9743772233
# ...

# %%
df.loc[1:4] #explicit indexing - includes last 4 row as well in the range
# Out:
#                                                  url  \
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_tables  Voting                             phone  \
# 1          Yes          No     787                      080 41714161
# 2          Yes          No     918                    +91 9663487993
# 3           No          No      88                    +91 9620009302
# ...

# %%
df.iloc[1:4] #implicit indexing - includes till 3 row - last 4 is not included from the range
# Out:
#                                                  url  \
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
#
#                                              address                   name  \
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
#
#   online_order book_tables  Voting           phone      location  \
# 1          Yes          No     787    080 41714161  Banashankari
# 2          Yes          No     918  +91 9663487993  Banashankari
# 3           No          No      88  +91 9620009302  Banashankari
#
#              rest_type                                         dish_liked  \
# 1        Casual Dining  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# ...

# %%
df_new.head()
# Out:
#                                                                      url  \
# name
# Jalsa                  https://www.zomato.com/bangalore/jalsa-banasha...
# Spice Elephant         https://www.zomato.com/bangalore/spice-elephan...
# San Churro Cafe        https://www.zomato.com/SanchurroBangalore?cont...
# Addhuri Udupi Bhojana  https://www.zomato.com/bangalore/addhuri-udupi...
# Grand Village          https://www.zomato.com/bangalore/grand-village...
#
#                                                                  address  \
# name
# Jalsa                  942, 21st Main Road, 2nd Stage, Banashankari, ...
# Spice Elephant         2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# San Churro Cafe        1112, Next to KIMS Medical College, 17th Cross...
# Addhuri Udupi Bhojana  1st Floor, Annakuteera, 3rd Stage, Banashankar...
# Grand Village          10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
#
#                       online_order book_tables  Voting  \
# name
# ...

# %%
df_new.reset_index()
# Out:
#                                                     name  \
# 0                                                  Jalsa
# 1                                         Spice Elephant
# 2                                        San Churro Cafe
# 3                                  Addhuri Udupi Bhojana
# 4                                          Grand Village
# ...                                                  ...
# 23188                                 Izakaya Gastro Pub
# 23189        M Bar - Bengaluru Marriott Hotel Whitefield
# 23190                             Keys Cafe - Keys Hotel
# 23191                                            Bhagini
# 23192  Chime - Sheraton Grand Bengaluru Whitefield Ho...
#
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# ...

# %%
df.reset_index(drop=True)
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 23188  https://www.zomato.com/bangalore/izakaya-gastr...
# 23189  https://www.zomato.com/bangalore/m-bar-bengalu...
# 23190  https://www.zomato.com/bangalore/keys-cafe-key...
# 23191  https://www.zomato.com/bangalore/bhagini-2-whi...
# 23192  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
#Select first two row and first two columns
df.iloc[0:2,0:2]
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
#
#                                              address
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...

# %%
# Example DataFrame
data = {
    "Restaurant": ["R1", "R2", "R3", "R4"],
    "Votes": [120, 240, 150, 80],
    "Rating": [4.1, 4.5, 3.9, 4.0]
}

sample_df = pd.DataFrame(data)
sample_df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9
# 3         R4     80     4.0

# %%
# Assigning new values to multiple rows and columns
sample_df.iloc[1:3, 1:3] = [[300, 4.7], [180, 4.2]]

print("DataFrame after modifying rows and columns:")
sample_df
# Out:
# DataFrame after modifying rows and columns:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    300     4.7
# 2         R3    180     4.2
# 3         R4     80     4.0

# %%
# Setting 'Restaurant' as the index
df_explicit = sample_df.set_index("Restaurant")
df_explicit
# Out:
#             Votes  Rating
# Restaurant
# R1            120     4.1
# R2            300     4.7
# R3            180     4.2
# R4             80     4.0

# %%
# Select specific rows ('R2' and 'R3') and specific columns ('Votes')
print(df_explicit.loc[["R2", "R3"], ["Votes"]])
print("==="*10)

# Updating the 'Votes' for restaurant 'R2'
df_explicit.loc["R2", "Votes"] = 350
print("Updated DataFrame:")
df_explicit
# Out:
#             Votes
# Restaurant
# R2            300
# R3            180
# ...
# Updated DataFrame:
#             Votes  Rating
# Restaurant
# R1            120     4.1
# R2            350     4.7
# R3            180     4.2
# R4             80     4.0

# %%
df_explicit.loc[df_explicit['Votes']>200] #restuarents which have votes greater than 200
# Out:
#             Votes  Rating
# Restaurant
# R2            350     4.7

# %%
df_explicit.loc[df_explicit['Rating']>4.5]
# Out:
#             Votes  Rating
# Restaurant
# R2            350     4.7

# %%
df_explicit.iloc[df_explicit.iloc[2] > 4.5]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-2b014d8d2418> in <cell line: 0>()
# ----> 1 df_explicit.iloc[df_explicit.iloc[2] > 4.5]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#    1192
#    1193     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1736
#    1737         if com.is_bool_indexer(key):
# -> 1738             self._validate_key(key, axis)
#    1739             return self._getbool_axis(key, axis=axis)
#    1740
#
# ...

# %% [markdown]
# When you apply the .unique() method on the series it gives you the unique values of the series
#
#
# When you apply the .nunique() method on the dataframe it gives you the number of unique value count in each column
#
# when you apply for .unique() method on the dataframe it gives the erro because all series has different datatype and it is to much for this function to return values for each series in dataframe
#
# When you apply the .nunique() method on the series it gives you the count of unique values in the column

# %% [markdown]
# Concatenate

# %%
# Creating a second DataFrame
data2 = {
    "Restaurant": ["R5", "R6"],
    "Votes": [90, 110],
    "Rating": [3.8, 4.3]
}

df2 = pd.DataFrame(data2)

# %%
df2
# Out:
#   Restaurant  Votes  Rating
# 0         R5     90     3.8
# 1         R6    110     4.3

# %%
sample_df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    300     4.7
# 2         R3    180     4.2
# 3         R4     80     4.0

# %%
combined_df = pd.concat([df2,sample_df])
combined_df
# Out:
#   Restaurant  Votes  Rating
# 0         R5     90     3.8
# 1         R6    110     4.3
# 0         R1    120     4.1
# 1         R2    300     4.7
# 2         R3    180     4.2
# 3         R4     80     4.0

# %% [markdown]
# Explicit indexes = which are visible in the dataframe
#
# Implicit indexes are something which you cannot see in the dataframe specifically

# %%
combined_df.loc[1] #explicit indexes can be duplicate
# Out:
#   Restaurant  Votes  Rating
# 1         R6    110     4.3
# 1         R2    300     4.7

# %%
combined_df.iloc[1] #implict indexes which is obvious
# Out:
# Restaurant     R6
# Votes         110
# Rating        4.3
# Name: 1, dtype: object

# %%
combined_df = pd.concat([df2,sample_df],ignore_index=True) #remove the duplicate explicit indexes from the dataframe
combined_df
# Out:
#   Restaurant  Votes  Rating
# 0         R5     90     3.8
# 1         R6    110     4.3
# 2         R1    120     4.1
# 3         R2    300     4.7
# 4         R3    180     4.2
# 5         R4     80     4.0

# %% [markdown]
# Column concatenation

# %%
new_columns = {
    "Dilvery Time (mins)": [30,25,35,20,40,28]
    }

df_new_col = pd.DataFrame(new_columns)

final_df = pd.concat([combined_df,df_new_col],axis=1)

final_df
# Out:
#   Restaurant  Votes  Rating  Dilvery Time (mins)
# 0         R5     90     3.8                   30
# 1         R6    110     4.3                   25
# 2         R1    120     4.1                   35
# 3         R2    300     4.7                   20
# 4         R3    180     4.2                   40
# 5         R4     80     4.0                   28

# %%
# Example DataFrame
data = {
    "Restaurant": ["R1", "R2", "R3", "R2", "R4", "R1"],
    "Votes": [120, 240, 150, 240, 80, 120],
    "Rating": [4.1, 4.5, 3.9, 4.5, 4.0, 4.1]
}

sample_df = pd.DataFrame(data)
sample_df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9
# 3         R2    240     4.5
# 4         R4     80     4.0
# 5         R1    120     4.1

# %%
sample_df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
sample_df.drop_duplicates()
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9
# 4         R4     80     4.0

# %%
sample_df.drop_duplicates().reset_index()
# Out:
#    index Restaurant  Votes  Rating
# 0      0         R1    120     4.1
# 1      1         R2    240     4.5
# 2      2         R3    150     3.9
# 3      4         R4     80     4.0

# %%
sample_df.drop_duplicates().reset_index(drop=True)
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9
# 3         R4     80     4.0

# %%
sample_df.duplicated(keep='last')

# %% [markdown]
# Aggregation

# %%
sample_df['Rating'].sum()

# %%
print(sample_df['Rating'].count())
print(sample_df['Rating'].mean())
print(sample_df['Rating'].min())
print(sample_df['Rating'].max())

# %%
sample_df[['Rating','Votes']].agg(['sum','count','mean','max'],)

# %%
sample_df.sort_values(by='Votes')

# %%
sample_df.sort_values(by='Votes',ascending=False)

# %%
sample_df.sort_values(by=['Votes','Rating'],ascending=[False,True])
